# %%
import pandas as pd
import mysql.connector
from mysql.connector import Error
"""
    1. Remove Irrelevant Rows and columns
        1.a Get rid of main_catergory, pledged, goal, usd pledged and Unnamed: 15
        1.b Get rid of Rows that contain canceled
    2. Get rid of time in "launched"  
        2.a Make sure all data in "launched is of right format"
    3. Check for duplicates, and remove them 
    4. Check for empty (null) values
"""
#reads data
data = pd.read_csv('kickstarterProjectsSnippet.csv')

#checks data before 
data.head(30)
# Out:
#             ID                                               name  \
# 0   1000002330                    The Songs of Adelaide & Abullah
# 1   1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2   1000004038                                     Where is Hank?
# 3   1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4   1000011046  Community Film Project: The Art of Neighborhoo...
# 5   1000014025                               Monarch Espresso Bar
# 6   1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 7   1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 8   1000034518  SPIN - Premium Retractable In-Ear Headphones w...
# 9    100004195  STUDIO IN THE SKY - A Documentary Feature Film...
# 10   100004721                                Of Jesus and Madmen
# 11   100005484                                   Lisa Lim New CD!
# 12  1000055792                                 The Cottage Market
# 13  1000056157  G-Spot Place for Gamers to connect with eachot...
# 14  1000057089  Tombstone: Old West tabletop game and miniatur...
# 15  1000064368                                     Survival Rings
# 16  1000064918                                          The Beard
# 17  1000068480                   Notes From London: Above & Below
# 18  1000070642                Mike Corey's Darkness & Light Album
# 19  1000071625                                           Boco Tea
# 20  1000072011              CMUK. Shoes: Take on Life Feet First.
# 21  1000081649                   MikeyJ clothing brand fundraiser
# 22  1000082254                     Alice in Wonderland in G Minor
# 23  1000087442  Mountain brew: A quest for alcohol sustainability
# 24  1000091520                        The Book Zoo - A Mini-Comic
# 25  1000102741  Matt Cavenaugh & Jenny Powers make their 1st a...
# 26  1000103948                               Superhero Teddy Bear
# 27  1000104688                                Permaculture Skills
# 28  1000104953  Rebel Army Origins: The Heroic Story Of Major ...
# 29   100011318                      My Moon - Animated Short Film
#
#           category main_category currency    deadline      goal  \
# 0           Poetry    Publishing      GBP   10/9/2015    1000.0
# 1   Narrative Film  Film & Video      USD   11/1/2017   30000.0
# 2   Narrative Film  Film & Video      USD   2/26/2013   45000.0
# 3            Music         Music      USD   4/16/2012    5000.0
# 4     Film & Video  Film & Video      USD   8/29/2015   19500.0
# 5      Restaurants          Food      USD    4/1/2016   50000.0
# 6             Food          Food      USD  12/21/2014    1000.0
# 7           Drinks          Food      USD   3/17/2016   25000.0
# 8   Product Design        Design      USD   5/29/2014  125000.0
# 9      Documentary  Film & Video      USD   8/10/2014   65000.0
# 10      Nonfiction    Publishing      CAD   10/9/2013    2500.0
# 11      Indie Rock         Music      USD    4/8/2013   12500.0
# 12          Crafts        Crafts      USD   10/2/2014    5000.0
# 13           Games         Games      USD   3/25/2016  200000.0
# 14  Tabletop Games         Games      GBP    5/3/2017    5000.0
# 15          Design        Design      USD   2/28/2015    2500.0
# 16     Comic Books        Comics      USD   11/8/2014    1500.0
# 17       Art Books    Publishing      USD   5/10/2015    3000.0
# 18           Music         Music      USD   8/17/2012     250.0
# 19            Food          Food      USD    6/2/2012    5000.0
# 20         Fashion       Fashion      USD  12/30/2013   20000.0
# 21   Childrenswear       Fashion      AUD    9/7/2017    2500.0
# 22         Theater       Theater      USD   6/15/2014    3500.0
# 23          Drinks          Food      NOK   2/25/2015     500.0
# 24          Comics        Comics      USD  11/12/2014     175.0
# 25           Music         Music      USD    1/6/2011   10000.0
# 26             DIY        Crafts      GBP    1/5/2016   12000.0
# 27       Webseries  Film & Video      CAD  12/14/2014   17757.0
# 28          Comics        Comics      GBP   1/28/2016     100.0
# 29       Animation  Film & Video      USD    5/3/2017   50000.0
#
#             launched   pledged       state  backers country  usd pledged  \
# 0    8/11/2015 12:12      0.00      failed        0      GB         0.00
# 1      9/2/2017 4:43   2421.00      failed       15      US       100.00
# 2     1/12/2013 0:20    220.00      failed        3      US       220.00
# 3     3/17/2012 3:24      1.00      failed        1      US         1.00
# 4      7/4/2015 8:35   1283.00    canceled       14      US      1283.00
# 5    2/26/2016 13:38  52375.00  successful      224      US     52375.00
# 6    12/1/2014 18:30   1205.00  successful       16      US      1205.00
# 7     2/1/2016 20:05    453.00      failed       40      US       453.00
# 8    4/24/2014 18:14   8233.00    canceled       58      US      8233.00
# 9    7/11/2014 21:55   6240.57    canceled       43      US      6240.57
# 10    9/9/2013 18:19      0.00      failed        0      CA         0.00
# 11     3/9/2013 6:42  12700.00  successful      100      US     12700.00
# 12    9/2/2014 17:11      0.00      failed        0      US         0.00
# 13    2/9/2016 23:01      0.00      failed        0      US         0.00
# 14    4/5/2017 19:44  94175.00  successful      761      GB     57763.78
# 15    1/29/2015 2:10    664.00      failed       11      US       664.00
# 16   10/9/2014 22:27    395.00      failed       16      US       395.00
# 17   4/10/2015 21:20    789.00      failed       20      US       789.00
# 18    8/2/2012 14:11    250.00  successful        7      US       250.00
# 19    5/3/2012 17:24   1781.00      failed       40      US      1781.00
# 20   11/25/2013 7:06  34268.00  successful      624      US     34268.00
# 21     8/8/2017 1:20      1.00      failed        1      AU         0.00
# 22   5/16/2014 10:10    650.00      failed       12      US       650.00
# 23   1/26/2015 19:17     48.00      failed        3      NO         6.18
# 24  10/23/2014 17:15    701.66  successful       66      US       701.66
# 25   12/7/2010 23:16  15827.00  successful      147      US     15827.00
# 26   12/6/2015 20:09      0.00      failed        0      GB         0.00
# 27  11/14/2014 18:02  48905.00  successful      571      CA     43203.25
# 28  12/29/2015 16:59    112.38  successful       27      GB       167.70
# 29    4/3/2017 17:11  57577.31  successful      840      US     10120.00
#
#     usd_pledged_real  usd_goal_real
# 0               0.00        1533.95
# 1            2421.00       30000.00
# 2             220.00       45000.00
# 3               1.00        5000.00
# 4            1283.00       19500.00
# 5           52375.00       50000.00
# 6            1205.00        1000.00
# 7             453.00       25000.00
# 8            8233.00      125000.00
# 9            6240.57       65000.00
# 10              0.00        2406.39
# 11          12700.00       12500.00
# 12              0.00        5000.00
# 13              0.00      200000.00
# 14         121857.33        6469.73
# 15            664.00        2500.00
# 16            395.00        1500.00
# 17            789.00        3000.00
# 18            250.00         250.00
# 19           1781.00        5000.00
# 20          34268.00       20000.00
# 21              0.81        2026.10
# 22            650.00        3500.00
# 23              6.29          65.55
# 24            701.66         175.00
# 25          15827.00       10000.00
# 26              0.00       17489.65
# 27          42174.03       15313.04
# 28            160.60         142.91
# 29          57577.31       50000.00

# %%
#get rid of duplicates, keeps first valid entry
data = data.drop_duplicates(subset = 'ID', keep = 'first')

#getting rid of unwanted / irrelavant columns
data_df = pd.DataFrame(data, columns = ['ID',
                                        'name',
                                        'category',
                                        'main_category',
                                        'deadline',
                                        'launched',
                                        'state',
                                        'backers',
                                        'country',
                                        'usd_pledged_real',
                                        'usd_goal_real' ])

#getting rid of empty data , and empty column 
data_df.drop(data.columns[data.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

#getting rid of all irrelevant  "canceled state" row entries as well as countries that have "N,0" as a entry
data_df.drop(data.loc[data['state'] == 'canceled'].index, inplace = True)
data_df.drop(data.loc[data['country'] == 'N,0"'].index, inplace = True)


#getting rid of time from launched
data['launched'] = pd.to_datetime(data['launched']).dt.date

#changing data to correct data type
data_df['ID'] = data_df['ID'].astype(int)
data_df['name'] = data['name'].astype(str)
data_df['category'] = data['category'].astype(str)
data_df['state'] = data['state'].astype(str)
data_df['deadline'] = data['deadline'].astype('datetime64[ns]')
data_df['launched'] = data['launched'].astype('datetime64[ns]')
#data_df['usd_pledged_real'] = data_df['usd_pledged_real'].astype(float)
#data_df['backers'] = data_df['backers'].astype(int)

#shows the cleaned data
data_df.head(-100)
# Out:
#              ID                                               name  \
# 0    1000002330                    The Songs of Adelaide & Abullah
# 1    1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2    1000004038                                     Where is Hank?
# 3    1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 5    1000014025                               Monarch Espresso Bar
# ..          ...                                                ...
# 887   100438743                           Love. Guts. High School.
# 888  1004394288                                      CAFE GANGSTER
# 889  1004399460                       Rivers Monroe Fall Tour 2016
# 891  1004405723  Golf Alpha Yankee: An LGBT Human Rights Docume...
# 892  1004405919  Colombian art gallery in LA: The Magic Realism...
#
#            category main_category   deadline   launched       state  backers  \
# 0            Poetry    Publishing 2015-10-09 2015-08-11      failed        0
# 1    Narrative Film  Film & Video 2017-11-01 2017-09-02      failed       15
# 2    Narrative Film  Film & Video 2013-02-26 2013-01-12      failed        3
# 3             Music         Music 2012-04-16 2012-03-17      failed        1
# 5       Restaurants          Food 2016-04-01 2016-02-26  successful      224
# ..              ...           ...        ...        ...         ...      ...
# 887         Theater       Theater 2012-04-16 2012-03-13  successful       71
# 888       Webseries  Film & Video 2014-09-24 2014-08-25      failed       17
# 889             Pop         Music 2016-10-24 2016-10-10  successful       20
# 891     Documentary  Film & Video 2014-08-18 2014-06-29  successful      439
# 892     Mixed Media           Art 2014-10-04 2014-09-04      failed       69
#
#     country  usd_pledged_real  usd_goal_real
# 0        GB              0.00        1533.95
# 1        US           2421.00       30000.00
# 2        US            220.00       45000.00
# 3        US              1.00        5000.00
# 5        US          52375.00       50000.00
# ..      ...               ...            ...
# 887      US           2667.00        2500.00
# 888      US           1220.00       15000.00
# 889      US           1310.00          25.00
# 891      US          42060.63       30000.00
# 892      US           1141.50       25000.00
#
# [805 rows x 11 columns]

# %%
#checking data types
data_df.dtypes
# Out:
# ID                           int32
# name                        object
# category                    object
# main_category               object
# deadline            datetime64[ns]
# launched            datetime64[ns]
# state                       object
# backers                      int64
# country                     object
# usd_pledged_real           float64
# usd_goal_real              float64
# dtype: object

# %%
#connecting to mysql
import mysql.connector
from mysql.connector import Error
try:
    #Attempt to connect
    connection = mysql.connector.connect(user = 'root',
                                         password = 'Combat69',
                                         host = '127.0.0.1',
                                         database = 'project')
    
    #get some information regarding our connections
    if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version: ", db_Info)
        cursor = connection.cursor()
        cursor.execute("SELECT database();")
        record = cursor.fetchone()
        print("You are connected to the database ", record)
        
        #creating database and tables
        cursor.execute("CREATE DATABASE projectDB")
        
        #creating tables
        #project table
        cursor.execute('''CREATE TABLE `projectdb`.`projects` (
                          `ID` INT NOT NULL,
                          `name` VARCHAR(255) NULL,
                          `category` VARCHAR(255) NULL,
                          `main_category` VARCHAR(255) NULL,
                          `country` VARCHAR(255) NULL,
                          `state` VARCHAR(255) NULL,
                          PRIMARY KEY (`ID`));''')
        
        #backer table
        cursor.execute('''CREATE TABLE `projectdb`.`backer` (
                          `ID` INT NOT NULL,
                          `Backers` VARCHAR(255) NULL,
                          `usd_pledged` FLOAT NULL,
                          `usd_goal` FLOAT NULL,
                          PRIMARY KEY (`ID`));''')
        
        cursor.execute('''CREATE TABLE `projectdb`.`funding_goal` (
                          `ID` INT NOT NULL,
                          `launched` DATE NULL,
                          `deadline` DATE NULL,
                          `usd_goal` FLOAT NULL,
                          `state` VARCHAR(255) NULL,
                          PRIMARY KEY (`ID`));''')
        
        #adding foreign key constraints
        cursor.execute('''ALTER TABLE `projectdb`.`backer` 
                            ADD CONSTRAINT `ID`
                              FOREIGN KEY (`ID`)
                              REFERENCES `projectdb`.`projects` (`ID`)
                              ON DELETE NO ACTION
                              ON UPDATE NO ACTION;''')
        
except Error as e:
    print("Error while connecting to MySQL", e)
    
finally:
    if connection.is_connected():
        cursor.close()
        connection.close()
        print("MySQL connection is closed.")
# Out:
# Connected to MySQL Server version:  8.0.22
# You are connected to the database  ('project',)
# MySQL connection is closed.

# %%
#inserting data into the tables created
try:
    #Attempt to connect
    connection = mysql.connector.connect(user = 'root',
                                         password = 'Combat69',
                                         host = '127.0.0.1',
                                         database = 'project')
    
    #get some information regarding our connections
    if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version: ", db_Info)
        cursor = connection.cursor()
        cursor.execute("SELECT database();")
        record = cursor.fetchone()
        print("You are connected to the database ", record)
        
        
        #uploading data to project table
        for row in data_df.itertuples():
            cursor.execute('''INSERT INTO projectDB.projects (ID, name, category, main_category, country, state)
                            VALUES (%s, %s, %s, %s, %s, %s)''',
                           (row.ID,
                            row.name,
                            row.category,
                            row.main_category,
                            row.country,
                            row.state))
            connection.commit()
            
        #uploading data to backer table
        for row in data_df.itertuples():
            cursor.execute('''INSERT INTO projectDB.backer (ID, backers, usd_pledged, usd_goal)
                            VALUES (%s, %s, %s, %s)''',
                          (row.ID,
                          row.backers,
                          row.usd_pledged_real,
                          row.usd_goal_real))
            connection.commit()
            
        #uploading data to funding_goal table
        for row in data_df.itertuples():
            cursor.execute('''INSERT INTO projectDB.funding_goal (ID, launched, deadline, usd_goal, state)
                            VALUES (%s, %s, %s, %s, %s)''',
                          (row.ID,
                          row.launched,
                          row.deadline,
                          row.usd_goal_real,
                          row.state,))
            connection.commit()
    
except Error as e:
    print("Error while connecting to MySQL", e)
    
finally:
    if connection.is_connected():
        cursor.close()
        connection.close()
        print("MySQL connection is closed.")
# Out:
# Connected to MySQL Server version:  8.0.22
# You are connected to the database  ('project',)
# MySQL connection is closed.

# %%
#Question 1 Which of the main categories has the most failed projects? 
connection = mysql.connector.connect(user = 'root',
                                         password = 'Combat69',
                                         host = '127.0.0.1',
                                         database = 'project')
cursor = connection.cursor()

cursor.execute('''SELECT p.main_category, p.state, count(p.id)
FROM project.projects as p 
WHERE p.state = 'failed'
GROUP BY p.main_category;''')

result = cursor.fetchall()
df = pd.DataFrame(data = result, columns = ['Main Category','Failed','# Failed Projects'])
df.sort_values(by='# Failed Projects',ascending=True, inplace=True)

connection.close()

#creating bar graph
df.plot.barh(x='Main Category',
                            y='# Failed Projects',
                            title="Failed Projects According to Category sorted by most failed projects",
                            color='red',
                            figsize=(20,10))

df.sort_values(by='# Failed Projects',ascending=False, inplace=True)
df
# Out:
#    Main Category  Failed  # Failed Projects
# 1   Film & Video  failed                 98
# 0          Music  failed                 63
# 3     Publishing  failed                 54
# 9          Games  failed                 45
# 8            Art  failed                 44
# 5     Technology  failed                 37
# 7         Design  failed                 36
# 12          Food  failed                 36
# 10       Fashion  failed                 34
# 4    Photography  failed                 17
# 13        Comics  failed                 16
# 11        Crafts  failed                 11
# 2        Theater  failed                  6
# 14    Journalism  failed                  5
# 6          Dance  failed                  3

# %%
#Question 2 Which of the main categories has the least failed projects?
connection = mysql.connector.connect(user = 'root',
                                         password = 'Combat69',
                                         host = '127.0.0.1',
                                         database = 'project')
cursor = connection.cursor()

cursor.execute('''SELECT p.main_category, p.state, count(p.id)
FROM project.projects as p 
WHERE p.state = 'failed'
GROUP BY p.main_category;''')

result = cursor.fetchall()
df = pd.DataFrame(data = result, columns = ['Main Category','Failed','# Failed Projects'])
df.sort_values(by='# Failed Projects',ascending=False, inplace=True)

connection.close()

#creating bar graph
df.plot.barh(x='Main Category',
                            y='# Failed Projects',
                            title="Failed Projects According to Category sorted by most failed projects",
                            color='teal',
                            figsize=(20,10))

df.sort_values(by='# Failed Projects',ascending=True, inplace=True)
df
# Out:
#    Main Category  Failed  # Failed Projects
# 6          Dance  failed                  3
# 14    Journalism  failed                  5
# 2        Theater  failed                  6
# 11        Crafts  failed                 11
# 13        Comics  failed                 16
# 4    Photography  failed                 17
# 10       Fashion  failed                 34
# 7         Design  failed                 36
# 12          Food  failed                 36
# 5     Technology  failed                 37
# 8            Art  failed                 44
# 9          Games  failed                 45
# 3     Publishing  failed                 54
# 0          Music  failed                 63
# 1   Film & Video  failed                 98

# %%
#Question 3 - How many projects succeeded with amount of backers between 20 and 40?
connection = mysql.connector.connect(user = 'root',
                                         password = 'Combat69',
                                         host = '127.0.0.1',
                                         database = 'project')

cursor = connection.cursor()

cursor.execute('''SELECT DISTINCT(p.name), b.backers, p.state
FROM project.projects as p, project.backer as b
WHERE p.ID = b.ID AND p.state = 'successful' AND b.backers <= 40 AND b.backers >= 20
ORDER BY b.backers;''')

result = cursor.fetchall()
df = pd.DataFrame(data = result, columns = ['Project Name', 'No. of Backers','State'])
df = df. sort_values(by = ['No. of Backers'])

connection.close()
df.head(30)
# Out:
#                                          Project Name  No. of Backers  \
# 0           Seeking Shelter Vol 3: Rescue Animals Ho!              20
# 1         Store Facades - Paintings out of Pittsburgh              20
# 2                                         Scar Tissue              20
# 3                                           FIREWATER              20
# 4                      The Unassisted EP 'Revolution'              20
# 5                        Rivers Monroe Fall Tour 2016              20
# 6   Hole in the Wall - Hector Records His Debut St...              20
# 7                               Wood Floor Fundraiser              21
# 8                            Winter Writing Residency              21
# 9                          The Promise - Tempus Films              21
# 10                           The Ainsley Band Uk Tour              21
# 11                           Bring Victorian to Life.              21
# 12           Help me publish my picture (kids) books!              22
# 13                                Gideon's Epic Forge              23
# 14  Shoot For Thrill or Shoot To Kill? Political S...              23
# 18                                             Hollow              24
# 17             Debut Original Album by Mindy Stratton              24
# 15  APP - CUSTOM SHOES/ Calzado Personalizado - MA...              24
# 16  Wheeling, Careening, and Wandering through the...              24
# 19                                      Happy Fix USA              25
# 20                The Womanhood Short Film Fundraiser              25
# 21         Dionysius Games - Indy Games for everyone.              25
# 22       Prelude - Psychological Survival Horror Game              25
# 26                                  Random Table Wiki              26
# 23                                    WrittenWitheArt              26
# 24  Help Put Community-Building Art in Austin's Pa...              26
# 25  First Solo exhibition in a recognised gallery,...              26
# 27  ThailandMike No.1, Portfolio, hiccup tour guid...              27
# 28  Rebel Army Origins: The Heroic Story Of Major ...              27
# 29                       Paterson Falls Film Festival              27
#
#          State
# 0   successful
# 1   successful
# 2   successful
# 3   successful
# 4   successful
# 5   successful
# 6   successful
# 7   successful
# 8   successful
# 9   successful
# 10  successful
# 11  successful
# 12  successful
# 13  successful
# 14  successful
# 18  successful
# 17  successful
# 15  successful
# 16  successful
# 19  successful
# 20  successful
# 21  successful
# 22  successful
# 26  successful
# 23  successful
# 24  successful
# 25  successful
# 27  successful
# 28  successful
# 29  successful

# %%
#Question 4 How many successful projects were there that had a time frame of less than 2 weeks
connection = mysql.connector.connect(user = 'root',
                                         password = 'Combat69',
                                         host = '127.0.0.1',
                                         database = 'project')

cursor = connection.cursor(buffered = True)


cursor.execute ('''SELECT p.name, f.launched, f.deadline, DATEDIFF(f.deadline,f.launched), p.state
FROM projects p , funding_goal f
WHERE f.ID = p.ID AND DATEDIFF(f.deadline,f.launched) <= 14 AND p.state = 'successful'
ORDER BY DATEDIFF(f.deadline,f.launched) DESC;''')

result = cursor.fetchall()

connection.close()
df = pd.DataFrame(data = result, columns = ['Name', 'Launched','Deadline','Timeframe in Days','State'])
df
# Out:
#                                                  Name    Launched    Deadline  \
# 0                                  DOGMA - Short Film  2015-03-06  2015-03-20
# 1   Day of the Dead Tyrion Lannister Calavera Viny...  2015-01-03  2015-01-17
# 2              Modern Handmade Ceramics: Paper & Clay  2013-05-10  2013-05-24
# 3                                          Money Shot  2013-09-04  2013-09-18
# 4   "Home is Where The Jug Is" Decal, T-shirt, Tro...  2013-09-06  2013-09-20
# 5                        Rivers Monroe Fall Tour 2016  2016-10-10  2016-10-24
# 6   Post Election Student Voices of Hope & Resistance  2016-12-08  2016-12-22
# 7                               Burning Manc Festival  2016-11-13  2016-11-26
# 8                  Ã¦mp:dance / amiti perry + company  2011-05-18  2011-05-30
# 9     Phil Younger - Slow Down (Official Music Video)  2016-12-09  2016-12-20
# 10   STEER: A Wearable Device That Can Save Your Life  2017-07-20  2017-07-31
# 11        Sci-Fi Janitors VS the Redbull Soapbox Race  2012-05-03  2012-05-13
# 12                               Dos Pueblos Tecnicos  2014-08-23  2014-09-02
# 13  Homestyle: Video Installation at Delicious Spe...  2014-04-02  2014-04-11
# 14               Bridge of Sighs Short Film -- Part 2  2012-11-08  2012-11-16
# 15                           The Amphibious Red Couch  2012-05-18  2012-05-26
# 16                          The Secret Tomato Project  2015-07-30  2015-08-06
# 17                           Bring Victorian to Life.  2013-10-15  2013-10-22
# 18                              Wood Floor Fundraiser  2015-08-11  2015-08-16
#
#     Timeframe in Days       State
# 0                  14  successful
# 1                  14  successful
# 2                  14  successful
# 3                  14  successful
# 4                  14  successful
# 5                  14  successful
# 6                  14  successful
# 7                  13  successful
# 8                  12  successful
# 9                  11  successful
# 10                 11  successful
# 11                 10  successful
# 12                 10  successful
# 13                  9  successful
# 14                  8  successful
# 15                  8  successful
# 16                  7  successful
# 17                  7  successful
# 18                  5  successful

# %%
#Question 5 What are the different success rates of each country ?
connection = mysql.connector.connect(user = 'root',
                                         password = 'Combat69',
                                         host = '127.0.0.1',
                                         database = 'project')
cursor = connection.cursor()

cursor.execute('''SELECT country,ROUND((Sucessful_Kickstarters/Kickstarters)*100,0) AS "%_of_Success" FROM 
                        (SELECT country,COUNT(country) AS 'Kickstarters',CAST(SUM(if(state = 'successful', 1, 0 ) )AS SIGNED) AS 'Sucessful_Kickstarters'
                            FROM projects
                            GROUP BY country)sub
                        GROUP BY country''')
result_percent_success_country = cursor.fetchall()
    
#creating a dataframe based off what we got from SQL
df_percentage = pd.DataFrame(result_percent_success_country, columns=['Country', '% of Success'])
df_percentage['% of Success'] = df_percentage['% of Success'].astype(int)

connection.close()

#sorted by %of success
df_percentage.sort_values(by='% of Success', inplace=True)

#horizontal bar chart    
df_percentage.plot.barh(x='Country',
                            y='% of Success',
                            title="Differences in countries Sucess rates",
                            color='green',
                            figsize=(20,10))

#printing table query
df_percentage
# Out:
#    Country  % of Success
# 15      DK             0
# 14      AT             0
# 10      ES             0
# 4       FR            25
# 5       AU            25
# 6       DE            25
# 8       IT            25
# 3       MX            29
# 2       CA            30
# 9       IE            33
# 11      SE            33
# 0       US            44
# 1       GB            44
# 7       NO            50
# 16      BE            50
# 12      NZ           100
# 13      CH           100
# 17      HK           100
# 18      NL           100

# %%
#Question 6 - What’s the most common project type in the US?
connection = mysql.connector.connect(user = 'root',
                                         password = 'Combat69',
                                         host = '127.0.0.1',
                                         database = 'project')
cursor = connection.cursor()

cursor.execute('''SELECT p.main_category, p.country, count(p.id)
FROM project.projects as p 
WHERE p.country = 'US'
GROUP BY p.main_category; ''')

result = cursor.fetchall()
df = pd.DataFrame(data = result, columns = ['Main Category','Country','No. of Projects'])


ax = df.plot.pie(y = 'No. of Projects', figsize = (10,10))
ax.set_title('\nMost Common US Kickstarters\n', fontsize = 12, color = 'black')
ax.set_xlabel('Main Category', fontsize = 12, color = 'black')
ax.set_ylabel('No. of Projects', fontsize = 12, color = 'black')
ax
connection.close()
df
# Out:
#    Main Category Country  No. of Projects
# 0          Music      US              111
# 1   Film & Video      US              144
# 2        Theater      US               18
# 3            Art      US               75
# 4         Design      US               50
# 5    Photography      US               23
# 6          Dance      US                9
# 7     Publishing      US               58
# 8           Food      US               46
# 9        Fashion      US               39
# 10         Games      US               62
# 11    Journalism      US                5
# 12        Crafts      US               12
# 13        Comics      US               26
# 14    Technology      US               47

# %%
#Question 7 How many successful projects are in each main category?
connection = mysql.connector.connect(user = 'root',
                                         password = 'Combat69',
                                         host = '127.0.0.1',
                                         database = 'project')
cursor = connection.cursor()

cursor.execute('''SELECT p.main_category, count(p.id)
FROM project.projects as p 
WHERE p.STATE = 'successful'
GROUP BY p.main_category; ''')

result = cursor.fetchall()
df = pd.DataFrame(data = result, columns = ['Main Category', 'Successful Startups'])

ax = df.plot.pie(x = 'Main Category', y = 'Successful Startups',figsize = (10,10))
ax.set_title('\nSuccessful Startups for Each Main Category\n', fontsize = 12, color = 'blue')
ax.set_xlabel('Main Category', fontsize = 10, color = 'blue')
connection.close()
df
# Out:
#    Main Category  Successful Startups
# 0   Film & Video                   68
# 1          Music                   63
# 2            Art                   41
# 3         Design                   29
# 4     Publishing                   24
# 5     Technology                   24
# 6        Fashion                   18
# 7           Food                   22
# 8    Photography                   12
# 9          Games                   40
# 10    Journalism                    4
# 11        Crafts                    4
# 12        Comics                   17
# 13       Theater                   13
# 14         Dance                    6

# %%
#Question 8 How many successful kickstarters where there outside of US and Great Britain
connection = mysql.connector.connect(user = 'root',
                                         password = 'Combat69',
                                         host = '127.0.0.1',
                                         database = 'project')
cursor = connection.cursor()

cursor.execute("SELECT country,COUNT(country) AS 'Kickstarters',CAST(SUM(if(state = 'successful', 1, 0 ) )AS SIGNED) AS 'Sucessful_Kickstarters'FROM projects GROUP BY country; ")
result_country = cursor.fetchall()
df_country = pd.DataFrame(result_country, columns= ['Country', 'Amount of Kickstarters', 'Successful Kickstarters'])
    
#getting rid of us and gb data entry
df_country = df_country.drop([0])
df_country = df_country.drop([1])
    
#sorting by amount of kickstarters
df_country.sort_values(by='Amount of Kickstarters',ascending=False, inplace=True)
    
#question 1 "How many sucessful kickstarters where there outside of US and Great Britian"
df_country.plot.bar(x='Country',
            title="Successful Kickstarters to amount of kickstarters",
            figsize=(20,10))

connection.close()
df_country
# Out:
#    Country  Amount of Kickstarters  Successful Kickstarters
# 2       CA                      30                        9
# 5       AU                      12                        3
# 6       DE                       8                        2
# 8       IT                       8                        2
# 3       MX                       7                        2
# 4       FR                       4                        1
# 17      HK                       3                        3
# 11      SE                       3                        1
# 10      ES                       3                        0
# 9       IE                       3                        1
# 14      AT                       2                        0
# 15      DK                       2                        0
# 16      BE                       2                        1
# 7       NO                       2                        1
# 12      NZ                       1                        1
# 13      CH                       1                        1
# 18      NL                       1                        1

# %%
#Question 9 - What projects with the highest USD goals were active the longest?
connection = mysql.connector.connect(user = 'root',
                                         password = 'Combat69',
                                         host = '127.0.0.1',
                                         database = 'project')
cursor = connection.cursor()
cursor.execute('''SELECT f.id, f.launched, f.deadline, DATEDIFF(deadline,launched), f.usd_goal, f.state
FROM project.funding_goal as f 
ORDER BY f.usd_goal DESC; ''')

result = cursor.fetchall()
df = pd.DataFrame(data = result, columns = ['Project ID', 'Launched','Deadline','Timeframe','USD Goal','State'])

connection.close()
df.head(30)
# Out:
#     Project ID    Launched    Deadline  Timeframe   USD Goal       State
# 0   1004941506  2017-08-19  2017-10-18         60  1600770.0      failed
# 1   1001542282  2015-09-10  2015-11-09         60  1076400.0      failed
# 2   1003793542  2014-10-11  2014-12-10         60  1000000.0      failed
# 3   1001708060  2016-01-08  2016-03-08         60   500000.0      failed
# 4   1002745522  2014-08-12  2014-09-21         40   500000.0      failed
# 5   1004668657  2017-02-07  2017-04-08         60   500000.0  successful
# 6   1003928906  2015-10-10  2015-11-10         31   400000.0      failed
# 7   1003308182  2016-02-17  2016-03-18         30   398395.0      failed
# 8   1003240719  2015-04-29  2015-06-24         56   343712.0      failed
# 9   1000953875  2015-01-22  2015-03-23         60   300000.0      failed
# 10  1002720451  2014-07-14  2014-08-13         30   300000.0      failed
# 11  1002856989  2015-07-11  2015-08-10         30   300000.0      failed
# 12  1003666645  2012-04-06  2012-05-06         30   300000.0      failed
# 13  1000233415  2016-04-19  2016-06-18         60   250000.0      failed
# 14  1000535116  2012-09-28  2012-10-28         30   250000.0      failed
# 15  1000629643  2014-05-28  2014-07-08         41   250000.0  successful
# 16  1003515712  2015-05-18  2015-06-17         30   250000.0      failed
# 17  1004131124  2015-04-08  2015-04-14          6   250000.0      failed
# 18  1001494526  2017-09-07  2017-11-06         60   233081.0      failed
# 19  1000056157  2016-02-09  2016-03-25         45   200000.0      failed
# 20  1001502333  2017-09-19  2017-11-03         45   200000.0  successful
# 21  1002538085  2017-02-24  2017-03-25         29   190666.0      failed
# 22  1002098978  2016-03-21  2016-05-05         45   171405.0      failed
# 23  1002521611  2017-01-02  2017-02-01         30   150000.0      failed
# 24  1002789956  2014-08-01  2014-08-31         30   150000.0      failed
# 25  1003900292  2010-12-29  2011-01-29         31   150000.0      failed
# 26  1000514796  2012-09-06  2012-10-11         35   125000.0      failed
# 27  1003074300  2015-05-05  2015-06-02         28   120000.0      failed
# 28  1003329858  2014-03-06  2014-04-05         30   117000.0      failed
# 29  1004275298  2014-07-18  2014-08-17         30   110000.0      failed

# %%
#Question 10 What is the average amount pledged for each country?
connection = mysql.connector.connect(user = 'root',
                                         password = 'Combat69',
                                         host = '127.0.0.1',
                                         database = 'project')
cursor = connection.cursor()

cursor.execute('''SELECT P.COUNTRY, AVG(B.USD_pledged)
FROM project.projects as P, PROJECT.BACKER AS B
WHERE P.ID = B.ID
GROUP BY P.COUNTRY;''')

result = cursor.fetchall()
df = pd.DataFrame(data = result, columns = ['Country', 'Average Pledge'])
df = df. sort_values(by = ['Average Pledge'])

ax = df.plot.bar(x = 'Country', y = 'Average Pledge', color = 'blue', rot = 0, figsize = (10,10))
ax.set_title('\nAverage Pledge for Each Country\n', fontsize = 12, color = 'black')
ax.set_xlabel('Country', fontsize = 10, color = 'black')
ax.set_ylabel('Average Pledge', fontsize = 10, color = 'black')
ax.tick_params(axis = 'both', color = 'black', labelsize = 8)

connection.close()
df
# Out:
#    Country  Average Pledge
# 14      AT       19.065001
# 3       MX      436.475712
# 10      ES     1005.269984
# 7       NO     1204.619976
# 15      DK     1586.910049
# 5       AU     1985.151639
# 4       FR     2080.797526
# 11      SE     2254.496663
# 2       CA     2739.002051
# 16      BE     2846.250114
# 8       IT     3358.454995
# 13      CH     4009.530029
# 6       DE     5625.274861
# 1       GB     7241.469456
# 12      NZ     8226.900391
# 18      NL    11444.639648
# 9       IE    13777.623606
# 0       US    18559.178610
# 17      HK    89469.257161
